# %% [markdown]
# # K-means Clustering on the Iris Dataset
#
# This notebook demonstrates how to perform K-means clustering on the classic Iris dataset using Python, scikit-learn, and Google Colab.
# K-means is an unsupervised machine learning algorithm that groups data into clusters based on feature similarity.
#
# **In this notebook, you will:**
# - Load the Iris dataset directly from the UCI Machine Learning Repository
# - Apply K-means clustering to group the data into clusters
# - Visualize the resulting clusters
#
# No prior setup or downloads are required—simply run each cell to see the results!

# %%
# Install required packages and enable ipywidgets for progress bars
# %pip install ipywidgets pandas scikit-learn matplotlib shap

# Enable ipywidgets extension (for classic Jupyter Notebook only)
# %jupyter nbextension enable --py widgetsnbextension
# %jupyter nbextension install --py widgetsnbextension
# Out:
# Requirement already satisfied: ipywidgets in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (8.1.7)
# Requirement already satisfied: pandas in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: scikit-learn in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (1.7.0)
# Requirement already satisfied: matplotlib in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: shap in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (0.48.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipywidgets) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: numpy>=1.26.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from shap) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from shap) (0.61.2)
# Requirement already satisfied: cloudpickle in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from shap) (4.14.1)
# Requirement already satisfied: decorator in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from numba>=0.54->shap) (0.44.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/mcdaniel/Desktop/gh/fswl/azureml-example/venv3.12/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%jupyter` not found.

# %%
# Step 1: Import libraries

import pandas as pd                 # https://pandas.pydata.org/docs/
from sklearn.cluster import KMeans  # https://sklearn-features.readthedocs.io/en/stable/
import matplotlib.pyplot as plt     # https://matplotlib.org/stable/index.html
import shap                         # https://shap.readthedocs.io/en/latest/index.html

# %% [markdown]
# ## Step 2: Load the Iris dataset from UC Irvine.

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
df = pd.read_csv(url, header=None, names=cols)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Step 3: Prepare data (drop species column for clustering)

# %%
X = df.drop('species', axis=1)

# %% [markdown]
# ## Step 4: Run K-means clustering

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

# %% [markdown]
# ## Step 5: Show results

# %%
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  cluster
# 0           5.1          3.5           1.4          0.2  Iris-setosa        1
# 1           4.9          3.0           1.4          0.2  Iris-setosa        1
# 2           4.7          3.2           1.3          0.2  Iris-setosa        1
# 3           4.6          3.1           1.5          0.2  Iris-setosa        1
# 4           5.0          3.6           1.4          0.2  Iris-setosa        1

# %% [markdown]
# ## Step 6: Visualize clusters (using first two features)

# %%
plt.scatter(df['sepal_length'], df['sepal_width'], c=df['cluster'])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('K-means Clusters on Iris Dataset')
plt.show()

# %% [markdown]
# ## Step 7: Interpreting Results
#
# ### Expected results
#
# - Red dots are 'high features' (ie, a flower with long petals or wide sepals) whereas blue dots are 'low features' (ie, a flower with short petals or narrow sepals).
# - Petal length is the most powerful feature for separating flowers into clusters — consistent with biology (Setosa has short petals).
# - SHAP confirms that the clustering model primarily uses petal-related features to group the Iris species.
# - Clusters likely correspond well with the natural species grouping: Setosa, Versicolor, and Virginica.
#
# Each dot is a data point (a flower), and the position on the x-axis shows how much a feature influenced the model’s decision to assign that point to a particular cluster:
#
# 1. petal_length has the strongest influence overall:
# - Low petal length (blue) pushes the SHAP value left — strong influence toward one cluster (likely Setosa, which has short petals).
# - High petal length (red) pushes SHAP values right, indicating a pull toward a different cluster (likely Virginica).
#
# 2. sepal_length also plays an important role:
# - Higher sepal lengths (pink/red) increase SHAP values — influence toward a cluster with longer sepals.
# - Lower sepal lengths (blue) reduce SHAP impact, pulling the data toward a different group.
#
# 3. petal_width is moderately important:
# - Mostly contributes to negative SHAP values when small (blue), influencing Setosa classification again.
# - Larger widths push toward another cluster.
#
# 4. sepal_width has the least impact:
# - Its SHAP values are tightly centered around 0.
# - While it may help fine-tune cluster assignments, it isn’t a major driver of separation.
#
# ### Understanding your dataset quality
#
# #### Good dataset (like this one)
#
# Red and blue dots (high and low values) are clustered consistently on different sides of the SHAP axis for important features. This is what you should see in the Iris dataset.
#
# #### Warning signs of a bad dataset
#
# Contrastingly, if the Iris dataset were of poor quality, a SHAP plot might look like:
# - All SHAP values close to zero
# - Red and blue dots randomly spread left/right. This means the model doesn’t know whether a high or low value increases or decreases the cluster assignment, which would be a sign that the feature isn’t informative, possibly due to noise or label issues.
# - No obvious dominant feature
# - Features that shouldn’t matter (based on intuition) appear at the top
#
# - SHAP Values Near Zero for All Features. If all the dots cluster close to 0 for most features, it means:
#   - The model didn’t find any feature particularly helpful for clustering.
#   - This may happen if the features are noisy, corrupted, or irrelevant.
#   - For example: swapped columns, measurement errors, or missing data filled incorrectly.
#
# - Important Features Are Missing
#   - If you expected petal_length and petal_width to dominate (as in clean Iris data), but instead you see:
#   - sepal_width or a meaningless feature like row_id at the top,
#   - that suggests the real informative features were damaged or removed during preprocessing.
#
# - Too Much Variation Within a Feature. For a specific feature:
#   - If both red and blue dots appear on both sides of the SHAP axis without a clear pattern, the model is probably confused.
#   - That could mean inconsistent labels, overlapping distributions, or non-standardized input.

# %%
# SHAP expects a model with a predict method; for clustering, we can use the KMeans object.
explainer = shap.Explainer(kmeans.predict, X)
shap_values = explainer(X)

# Visualize SHAP values for the first cluster
shap.summary_plot(shap_values, X, show=True)
